# %%
# %run -i model10.py
# Out:
# Train on 4041 samples, validate on 449 samples
# Epoch 1/500
#  - 1s - loss: 1.4266 - acc: 0.4026 - val_loss: 1.0846 - val_acc: 0.4410
# Epoch 2/500
#  - 0s - loss: 1.1884 - acc: 0.4813 - val_loss: 0.9284 - val_acc: 0.5679
# Epoch 3/500
#  - 0s - loss: 1.0201 - acc: 0.5491 - val_loss: 0.8369 - val_acc: 0.6281
# Epoch 4/500
#  - 0s - loss: 0.9078 - acc: 0.6021 - val_loss: 0.7773 - val_acc: 0.6570
# Epoch 5/500
#  - 0s - loss: 0.8163 - acc: 0.6397 - val_loss: 0.7360 - val_acc: 0.6748
# Epoch 6/500
#  - 0s - loss: 0.7603 - acc: 0.6751 - val_loss: 0.7030 - val_acc: 0.6815
# Epoch 7/500
#  - 0s - loss: 0.6995 - acc: 0.7018 - val_loss: 0.6757 - val_acc: 0.6993
# Epoch 8/500
#  - 0s - loss: 0.6465 - acc: 0.7290 - val_loss: 0.6538 - val_acc: 0.7149
# Epoch 9/500
#  - 0s - loss: 0.6080 - acc: 0.7461 - val_loss: 0.6353 - val_acc: 0.7261
# Epoch 10/500
#  - 0s - loss: 0.5700 - acc: 0.7585 - val_loss: 0.6177 - val_acc: 0.7439
# Epoch 11/500
# ...
