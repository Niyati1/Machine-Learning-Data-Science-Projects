# %%
# %run -i autoencoder.py
# Out:
# (?, 128, 128, 1)
# (?, 128, 128, 8)
# (?, 64, 64, 8)
# (?, 64, 64, 16)
# (?, 32, 32, 16)
# (?, 8, 8, 32)
# (?, ?, ?, 32)
# (?, 64, 64, 32)
# (?, ?, ?, 16)
# (?, 128, 128, 16)
# (?, ?, ?, 1)
# Train on 12126 samples, validate on 1348 samples
# Epoch 1/50
# 12126/12126 [==============================] - 260s 21ms/step - loss: 0.8500 - val_loss: 0.6244
# Epoch 2/50
# 12126/12126 [==============================] - 262s 22ms/step - loss: 0.6283 - val_loss: 0.5965
# Epoch 3/50
# 12126/12126 [==============================] - 261s 22ms/step - loss: 0.6219 - val_loss: 0.5905
# Epoch 4/50
# 12126/12126 [==============================] - 260s 21ms/step - loss: 0.6068 - val_loss: 0.6265
# Epoch 5/50
# 12126/12126 [==============================] - 261s 21ms/step - loss: 0.6074 - val_loss: 0.5825
# Epoch 6/50
# 12126/12126 [==============================] - 262s 22ms/step - loss: 0.6086 - val_loss: 0.6041
# Epoch 7/50
# ...
