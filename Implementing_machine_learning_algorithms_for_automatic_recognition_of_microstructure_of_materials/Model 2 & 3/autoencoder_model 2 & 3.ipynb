# %%
from sklearn.cross_validation import cross_val_score
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
import sklearn
np.random.seed(0)
# Out:
# /home/shared/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
df = pd.read_csv('Dataset/all.csv', header=None)
print(df.shape)
# Out:
# (13475, 16384)

# %%
y = pd.read_csv('Dataset/labels_f.csv',dtype=str, header=None)
print(y.shape)
# Out:
# (13475, 1)

# %%
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
# Out:
# /home/shared/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
x_train,x_test,y_train,y_test = train_test_split(df,y, test_size=0.15)

# %%
# run for task 1
classifier = RandomForestClassifier(n_estimators=1000, criterion='gini' ,max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto', max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=100, random_state=None, verbose=2, warm_start=False)
# run for task 2
classifier = RandomForestClassifier(n_estimators=1000, criterion='gini' ,max_depth=None, min_samples_split=43, min_samples_leaf=45, min_weight_fraction_leaf=0.0, max_features='auto', max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=100, random_state=None, verbose=2, warm_start=False)
classifier.fit(x_train, y_train)
# Out:
# /home/shared/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# building tree 1 of 1000
# building tree 2 of 1000
# building tree 3 of 1000
# building tree 4 of 1000
# building tree 5 of 1000
# building tree 6 of 1000
# building tree 7 of 1000
# building tree 8 of 1000
# building tree 9 of 1000
# building tree 10 of 1000
# building tree 11 of 1000
# building tree 12 of 1000
# building tree 13 of 1000
# building tree 14 of 1000
# building tree 15 of 1000
# building tree 16 of 1000
# building tree 17 of 1000
# building tree 18 of 1000building tree 19 of 1000
# building tree 20 of 1000
# building tree 21 of 1000building tree 22 of 1000
# building tree 23 of 1000
# building tree 24 of 1000
# building tree 25 of 1000
# ...

# %%
y_pred = classifier.predict(x_test)
# Out:
# [Parallel(n_jobs=100)]: Done 165 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=100)]: Done 448 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=100)]: Done 1000 out of 1000 | elapsed:    0.4s finished

# %%
a =sklearn.metrics.accuracy_score(y_test, y_pred, normalize=True, sample_weight=None)

# %%
print(a*100)
print(classifier.score(x_test,y_test))
# Out:
# 61.81998021760633
# [Parallel(n_jobs=100)]: Done 165 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=100)]: Done 448 tasks      | elapsed:    0.2s
# 0.6181998021760633
# [Parallel(n_jobs=100)]: Done 1000 out of 1000 | elapsed:    0.4s finished
