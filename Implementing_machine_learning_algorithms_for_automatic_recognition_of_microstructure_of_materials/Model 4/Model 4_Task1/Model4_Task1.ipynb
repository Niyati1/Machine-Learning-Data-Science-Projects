# %%
# %run -i model.py
# Out:
# Train on 10606 samples, validate on 1179 samples
# Epoch 1/500
#  - 3s - loss: 1.9010 - acc: 0.3771 - val_loss: 1.4603 - val_acc: 0.5394
# Epoch 2/500
#  - 1s - loss: 1.2486 - acc: 0.6087 - val_loss: 1.1423 - val_acc: 0.6421
# Epoch 3/500
#  - 1s - loss: 0.9852 - acc: 0.7032 - val_loss: 0.9748 - val_acc: 0.7014
# Epoch 4/500
#  - 1s - loss: 0.8248 - acc: 0.7605 - val_loss: 0.8484 - val_acc: 0.7464
# Epoch 5/500
#  - 1s - loss: 0.7087 - acc: 0.8011 - val_loss: 0.7699 - val_acc: 0.7803
# Epoch 6/500
#  - 1s - loss: 0.6273 - acc: 0.8296 - val_loss: 0.7110 - val_acc: 0.7897
# Epoch 7/500
#  - 1s - loss: 0.5575 - acc: 0.8515 - val_loss: 0.6567 - val_acc: 0.7998
# Epoch 8/500
#  - 1s - loss: 0.5048 - acc: 0.8713 - val_loss: 0.6197 - val_acc: 0.8168
# Epoch 9/500
#  - 1s - loss: 0.4562 - acc: 0.8847 - val_loss: 0.5910 - val_acc: 0.8219
# Epoch 10/500
#  - 1s - loss: 0.4197 - acc: 0.8937 - val_loss: 0.5609 - val_acc: 0.8355
# Epoch 11/500
# ...
