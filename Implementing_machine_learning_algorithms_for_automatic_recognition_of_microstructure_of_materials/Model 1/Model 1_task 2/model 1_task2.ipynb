# %%
# %run -i model.py
# Out:
# Train on 10610 samples, validate on 1179 samples
# Epoch 1/50
#  - 59s - loss: 0.8937 - acc: 0.5904 - val_loss: 0.8433 - val_acc: 0.6090
# Epoch 2/50
#  - 57s - loss: 0.6863 - acc: 0.6889 - val_loss: 0.7021 - val_acc: 0.6819
# Epoch 3/50
#  - 57s - loss: 0.5580 - acc: 0.7469 - val_loss: 0.8011 - val_acc: 0.6633
# Epoch 4/50
#  - 57s - loss: 0.4320 - acc: 0.8130 - val_loss: 0.6953 - val_acc: 0.7065
# Epoch 5/50
#  - 57s - loss: 0.3392 - acc: 0.8604 - val_loss: 0.7546 - val_acc: 0.7099
# Epoch 6/50
#  - 56s - loss: 0.2420 - acc: 0.9068 - val_loss: 1.0216 - val_acc: 0.7074
# Epoch 7/50
#  - 56s - loss: 0.1715 - acc: 0.9365 - val_loss: 1.0658 - val_acc: 0.7099
# Epoch 8/50
#  - 57s - loss: 0.1653 - acc: 0.9356 - val_loss: 0.9865 - val_acc: 0.7388
# Epoch 9/50
#  - 57s - loss: 0.1324 - acc: 0.9498 - val_loss: 1.0807 - val_acc: 0.7167
# Epoch 10/50
#  - 57s - loss: 0.0940 - acc: 0.9652 - val_loss: 1.3969 - val_acc: 0.6870
# Epoch 11/50
# ...
